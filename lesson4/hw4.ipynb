# %% [markdown]
# - В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной филтьтрации?
#
#   * В гибридных системах мы используем матрицу признаков(фичей) плюс к матрице итеракций, а не только матрицу итеракций, как в ALS
#
#
# - Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы
#
#   * Чтобы решить проблему Холодного старта, мы можем использовать таблицу фичей, чтобы сделать наших изеров или товаров не нулевыми.
#   * Так же может помочь проблему с рекомендациями новых или нищевых товаров, к примеру фильмов, так как у нас уже есть инвормация по жанру, актерам и так далее(тобишь фичей)

# %% [markdown]
# Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить
#
# - Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах?
#   * Используется воронка фильтров(множество фильтров, а не один)
# - Какие проблемы могут возникнуть при выводе такой модели в продакшен?
#
#   * Как я понял основное, что это все долго считается.

# %% [markdown]
# В работе Data Scientist'а важную часть занимает research - исследование существующих архитектур и разбор научных статей, в которых они описываются. Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
#
# - Какой датасет используют авторы?
#   * MovieLens 10M датасет объединеный с Tag Genome сетом
#   * CrossValidated датасет
# - Что используют в качестве признаков?
#   * Для MovieLens: Жанр, и список меток(tags)
#   * Для CrossValidated: таги вопросов, мета юзеров(типо About Me)
# - С какими моделями сравнивают LightFM? Опишите их основные идеи кратко
#
#   * Стандартная факторизация матриц(MF): модель колаборативной фильтрации
#   * LSI-LR: модель контентной рекомендательной системы
#   * LSI-UP: гибридная модель
